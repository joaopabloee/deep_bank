# %%
# !pip install wandb

# %%
import wandb
import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-fc667cd1-154d-4e6e-9f56-e1ec9d7e4c86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc667cd1-154d-4e6e-9f56-e1ec9d7e4c86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-292f82be1b7a> in <module>()
#       1 from google.colab import files
#       2
# ----> 3 uploaded = files.upload()
#       4
#       5 for fn in uploaded.keys():
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      39   """
#      40
# ---> 41   uploaded_files = _upload_files(multiple=True)
#      42   # Mapping from original filename to filename as saved locally.
#      43   local_filenames = dict()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in _upload_files(multiple)
#     119   files = _collections.defaultdict(bytes)
#     120
# --> 121   while result['action'] != 'complete':
#     122     result = _output.eval_js(
#     123         'google.colab._files._uploadFilesContinue("{output_id}")'.format(
#
# TypeError: 'NoneType' object is not subscriptable

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

# read the dataset to a Pandas' dataframe
income = pd.read_csv("bank-full.csv", delimiter=';')
income.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
income.to_csv("raw_data.csv",index=False)

# %%
# Login to Weights & Biases
# !wandb login --relogin
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# Send the raw_data.csv to the Wandb storing it as an artifact
# !wandb artifact put \
      --name deep_learning/raw_data.csv \
      --type raw_data \
      --description "The raw data from bank marketing" raw_data.csv
# Out:
# wandb: Uploading file raw_data.csv to: "joaopabloee/deep_learning/raw_data.csv:latest" (raw_data)
# wandb: Currently logged in as: joaopablo (joaopabloee). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.21
# wandb: Run data is saved locally in /content/wandb/run-20220708_145229-36z92ptf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dashing-smoke-2
# wandb: ⭐️ View project at https://wandb.ai/joaopabloee/deep_learning
# wandb: 🚀 View run at https://wandb.ai/joaopabloee/deep_learning/runs/36z92ptf
# Artifact uploaded, use this artifact in a run by adding:
#
#     artifact = run.use_artifact("joaopabloee/deep_learning/raw_data.csv:latest")
#
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Synced dashing-smoke-2: https://wandb.ai/joaopabloee/deep_learning/runs/36z92ptf
# wandb: Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220708_145229-36z92ptf/logs

# %%
#end
